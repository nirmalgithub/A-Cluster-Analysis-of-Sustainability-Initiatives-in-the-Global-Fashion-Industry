# %% [markdown]
# # Add Company Performance Data
#
# =============================================================
#  Fashion Sustainability Dataset — Performance Data Updater
# =============================================================
#  Purpose: Add individual company sustainability report data
#           (Scope 1+2 emissions, renewable energy %, etc.)
#           to the master dataset as Perf_* columns.
#
#  Input:   Fashion_Sustainability_Final_Dataset.csv
#  Output:  Fashion_Sustainability_Final_Dataset.csv (updated in-place)
#
#  Usage:   Run after collecting company report data.
#           Update the PERFORMANCE_DATA dict below as you
#           collect data from each company's sustainability report.
# =============================================================

# %%
import pandas as pd
import numpy as np

CSV = 'Fashion_Sustainability_Final_Dataset.csv'
df  = pd.read_csv(CSV)

# %% [markdown]
# ## ADD PERFORMANCE COLUMNS IF NOT PRESENT

# %%
perf_cols = [
    'Perf_Scope1_2_Emissions_tCO2e',
    'Perf_Scope3_Emissions_tCO2e',
    'Perf_Baseline_Year',
    'Perf_Baseline_Emissions_tCO2e',
    'Perf_Carbon_Reduction_Target_pct',
    'Perf_Carbon_Target_Year',
    'Perf_NetZero_Target_Year',
    'Perf_Renewable_Energy_pct',
    'Perf_Recycled_Materials_pct',
    'Perf_Revenue_USD_M',
    'Perf_Employees',
    'Perf_Source_Report'
]
for col in perf_cols:
    if col not in df.columns:
        df[col] = None

# %% [markdown]
# ## PERFORMANCE DATA COLLECTED FROM COMPANY REPORTS

# %%
# Format: 'Exact Company Name as in dataset': { field: value }
# Add new companies here as you collect their reports.

PERFORMANCE_DATA = {
    'Adidas AG': {
        'Perf_Scope1_2_Emissions_tCO2e':    127983,
        'Perf_Scope3_Emissions_tCO2e':      6236869,
        'Perf_Baseline_Year':               2022,
        'Perf_Baseline_Emissions_tCO2e':    164149,
        'Perf_Carbon_Reduction_Target_pct': 70,
        'Perf_Carbon_Target_Year':          2030,
        'Perf_NetZero_Target_Year':         2050,
        'Perf_Renewable_Energy_pct':        36,
        'Perf_Recycled_Materials_pct':      43,
        'Perf_Revenue_USD_M':               26500,
        'Perf_Employees':                   59478,
        'Perf_Source_Report':               'Adidas Annual Report 2025 (ESRS E1-4, E1-5, E1-6, E5)',
    },
    'Asos': {
        'Perf_Scope1_2_Emissions_tCO2e':    6397,
        'Perf_Scope3_Emissions_tCO2e':      1224272,
        'Perf_Baseline_Year':               2022,
        'Perf_Baseline_Emissions_tCO2e':    1828661,
        'Perf_Carbon_Reduction_Target_pct': 90,
        'Perf_Carbon_Target_Year':          2030,
        'Perf_NetZero_Target_Year':         2050,
        'Perf_Renewable_Energy_pct':        80.3,
        'Perf_Recycled_Materials_pct':      None,
        'Perf_Revenue_USD_M':               None,
        'Perf_Employees':                   None,
        'Perf_Source_Report':               'ASOS Fashion with Integrity (FWI) Supplementary Information, updated 21 Nov 2025',
    },
    'American Eagle Outfitters': {
        'Perf_Scope1_2_Emissions_tCO2e':    None,
        'Perf_Scope3_Emissions_tCO2e':      None,
        'Perf_Baseline_Year':               2018,
        'Perf_Baseline_Emissions_tCO2e':    None,
        'Perf_Carbon_Reduction_Target_pct': 80,
        'Perf_Carbon_Target_Year':          2030,
        'Perf_NetZero_Target_Year':         None,
        'Perf_Renewable_Energy_pct':        24,
        'Perf_Recycled_Materials_pct':      62,
        'Perf_Revenue_USD_M':               None,
        'Perf_Employees':                   None,
        'Perf_Source_Report':               'AEO 2024 Building a Better World ESG Progress Report',
    },
    'Asics Corporation': {
        'Perf_Scope1_2_Emissions_tCO2e':    17565,
        'Perf_Scope3_Emissions_tCO2e':      776017,
        'Perf_Baseline_Year':               2015,
        'Perf_Baseline_Emissions_tCO2e':    30858,
        'Perf_Carbon_Reduction_Target_pct': 63,
        'Perf_Carbon_Target_Year':          2030,
        'Perf_NetZero_Target_Year':         2050,
        'Perf_Renewable_Energy_pct':        36.8,
        'Perf_Recycled_Materials_pct':      50,
        'Perf_Revenue_USD_M':               4480,
        'Perf_Employees':                   8987,
        'Perf_Source_Report':               'ASICS Sustainability Report 2024',
    },
    'Gap inc.': {
        'Perf_Scope1_2_Emissions_tCO2e':    115749,
        'Perf_Scope3_Emissions_tCO2e':      5799502,
        'Perf_Baseline_Year':               2017,
        'Perf_Baseline_Emissions_tCO2e':    388954,
        'Perf_Carbon_Reduction_Target_pct': 90,
        'Perf_Carbon_Target_Year':          2030,
        'Perf_NetZero_Target_Year':         2050,
        'Perf_Renewable_Energy_pct':        46,
        'Perf_Recycled_Materials_pct':      65,
        'Perf_Revenue_USD_M':               None,
        'Perf_Employees':                   None,
        'Perf_Source_Report':               'Gap Inc. 2025 Impact Report',
    },
    'Hugo Boss AG': {
        'Perf_Scope1_2_Emissions_tCO2e':    None,
        'Perf_Scope3_Emissions_tCO2e':      None,
        'Perf_Baseline_Year':               2024,
        'Perf_Baseline_Emissions_tCO2e':    None,
        'Perf_Carbon_Reduction_Target_pct': 50,
        'Perf_Carbon_Target_Year':          2030,
        'Perf_NetZero_Target_Year':         None,
        'Perf_Renewable_Energy_pct':        82,
        'Perf_Recycled_Materials_pct':      48,
        'Perf_Revenue_USD_M':               None,
        'Perf_Employees':                   None,
        'Perf_Source_Report':               'Hugo Boss Sustainability Report',
    },
    'Hanesbrands': {
        'Perf_Scope1_2_Emissions_tCO2e':    None,
        'Perf_Scope3_Emissions_tCO2e':      None,
        'Perf_Baseline_Year':               2019,
        'Perf_Baseline_Emissions_tCO2e':    None,
        'Perf_Carbon_Reduction_Target_pct': 50,
        'Perf_Carbon_Target_Year':          2030,
        'Perf_NetZero_Target_Year':         None,
        'Perf_Renewable_Energy_pct':        67,
        'Perf_Recycled_Materials_pct':      52,
        'Perf_Revenue_USD_M':               None,
        'Perf_Employees':                   None,
        'Perf_Source_Report':               'HBI 2024 Sustainability Summary Report',
    },
    'Burberry Group plc': {
        'Perf_Scope1_2_Emissions_tCO2e':    1430,
        'Perf_Scope3_Emissions_tCO2e':      275172,
        'Perf_Baseline_Year':               2016,
        'Perf_Baseline_Emissions_tCO2e':    None,
        'Perf_Carbon_Reduction_Target_pct': 95,
        'Perf_Carbon_Target_Year':          2027,
        'Perf_NetZero_Target_Year':         2050,
        'Perf_Renewable_Energy_pct':        84,
        'Perf_Recycled_Materials_pct':      None,
        'Perf_Revenue_USD_M':               3098,
        'Perf_Employees':                   7299,
        'Perf_Source_Report':               'Burberry Annual Report 2025/26',
    },
}

# %% [markdown]
# ## APPLY UPDATES

# %%
for company, fields in PERFORMANCE_DATA.items():
    mask = df['Company'] == company
    if mask.any():
        for field, value in fields.items():
            df.loc[mask, field] = value
        print(f"  ✅ Updated: {company}")
    else:
        print(f"  ⚠️  Not found in dataset: {company}")

# %% [markdown]
# ## SAVE

# %%
df.to_csv(CSV, index=False)
filled = df['Perf_Source_Report'].notna().sum()
print(f"\n✅ Saved. Companies with performance data: {filled}/{len(df)}")
